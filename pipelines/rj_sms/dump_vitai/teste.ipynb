# %%
import pandas as pd

# %%
df = pd.read_parquet("~/estoque_2023-08-20_clean.parquet")
df.head()
# Out:
#                                      id                     estabelecimentoId  \
# 0  D6B0B714-E4CA-40AE-8FC2-0CFFAFD59C69  EC2F837C-EF91-4FF3-BB6E-48C0C1D468BC
# 1  7EB6A2A3-33AB-42F0-94E1-4B1B9A74F78A  EC2F837C-EF91-4FF3-BB6E-48C0C1D468BC
# 2  9B40D134-F802-440E-876D-99DB7259566A  EC2F837C-EF91-4FF3-BB6E-48C0C1D468BC
# 3  EBD67445-AE4A-4660-A745-97B7073BFAD1  EC2F837C-EF91-4FF3-BB6E-48C0C1D468BC
# 4  42DD504C-29D6-4758-99F6-4D12820EABCC  EC2F837C-EF91-4FF3-BB6E-48C0C1D468BC
#
#       cnes  sigla produtocodigo  \
# 0  6716938  CERBT   85400001895
# 1  6716938  CERBT   65051900356
# 2  6716938  CERBT   65050900301
# 3  6716938  CERBT   65100500506
# 4  6716938  CERBT   65052900562
#
#                                            descricao         grupo  \
# 0  FRALDA DESCARTAVEL ADULTO, GRANDE, FITA ADESIV...  NO INFORMADO
# 1                         BIPERIDENO, CLORIDRATO 2MG   CONTROLADOS
# 2              HEPARINA SODICA 5000UI  AMPOLA 0,25ML  NO INFORMADO
# ...

# %%
# Out:
#                                          id  \
# 155    AEE262CB-74A9-464E-B9D5-1F162E566A2D
# 156    19A987AA-A801-49B2-8FEF-16EC42C1CB98
# 157    17E2968A-67B6-4027-B288-79D64626AF2B
# 158    A5A0633B-1027-451B-AF81-842BE93A0F5A
# 159    EC841DAA-481C-48BA-8C6C-098ADD8A9DFB
# ...                                     ...
# 19984  7D91A050-109B-49D1-B2D6-B5E5EFEB1CAA
# 19986  1B135ACD-6A08-404F-8F49-67220ED70153
# 19988  88688B00-4B77-4C9F-B9D3-107593158907
# 19989  A86941EE-18A7-4DAD-9857-5B4615C6FF26
# 20080  D15697A1-1B7E-4951-9EFB-38ABF5851C5C
#
#                           estabelecimentoId     cnes  sigla    produtocodigo  \
# 155    701FC25A-3601-4F95-8F13-FF6D74AE9484  0932280  UPADC      65051101399
# 156    701FC25A-3601-4F95-8F13-FF6D74AE9484  0932280  UPADC  65.20.21.020-38
# 157    701FC25A-3601-4F95-8F13-FF6D74AE9484  0932280  UPADC      65202927576
# 158    701FC25A-3601-4F95-8F13-FF6D74AE9484  0932280  UPADC      65202915640
# ...
